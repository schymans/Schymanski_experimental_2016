# %% [markdown]
# # Table of symbolic variables used in other worksheets
# Below, we import variables and their definitions and units from other worksheets and display them in a sorted table. We also generate latex code for inclusion in manuscript.

# %%
# %%capture storage
# The above redirects all output of the below commands to the variable 'storage' instead of displaying it.
# It can be viewed by typing: 'storage()'
# Setting up worksheet and importing equations for explicit leaf energy balance
load('temp/Worksheet_setup.sage')

# %%
# List all .ipynb files
list_files = os.listdir('.')
for fname in list_files:
    if fname[-5:] == 'ipynb':
        print fname
# Out:
# Tables_of_variables.ipynb
# perforated_foils_data.ipynb
# leaf_enbalance2s_eqs.ipynb
# Worksheet_setup.ipynb
# stomatal_cond_eqs.ipynb
# leaf_chamber_eqs.ipynb
# perforated_foils_data-Copy1.ipynb
# leaf_chamber_data.ipynb
# leaf_enbalance_eqs.ipynb
# E_PM_eqs.ipynb

# %%
# From leaf_chamber_eqs, Leaf_enbalance2s_eqs and stomatal_cond_eqs
load_session('temp/leaf_enbalance2s_eqs.sobj')
docdict1 = docdict.copy()
udict1 = udict.copy()
cdict1 = cdict.copy()
load_session('temp/leaf_chamber_eqs.sobj')
docdict1.update(docdict)
udict1.update(udict)
cdict1.update(cdict)
load_session('temp/stomatal_cond_eqs.sobj')
docdict1.update(docdict)
udict1.update(udict)
cdict1.update(cdict)
docdict = docdict1
udict = udict1
cdict = cdict1

# %%
# Creating dictionary to substitute names of units with shorter forms
var('m s J Pa K kg mol')
subsdict = {meter: m, second: s, joule: J, pascal: Pa, kelvin: K, kilogram: kg, mole: mol}
var('N_Re_L N_Re_c N_Le N_Nu_L N_Gr_L N_Sh_L')
dict_varnew = {Re: N_Re_L, Re_c: N_Re_c, Le: N_Le, Nu: N_Nu_L, Gr: N_Gr_L, Sh: N_Sh_L}
dict_varold = {v: k for k, v in dict_varnew.iteritems()}
variables = sorted([str(variable.subs(dict_varnew)) for variable in udict.keys()],key=str.lower)
tableheader = [('Variable', 'Description (value)', 'Units')]
tabledata = [('Variable', 'Description (value)', 'Units')]
for variable1 in variables:
    variable2 = eval(variable1).subs(dict_varold)
    variable = str(variable2)
    tabledata.append((eval(variable),docdict[eval(variable)],fun_units_formatted(variable)))

table(tabledata, header_row=True)
# Out:
#   Variable     Description (value)                                                                                                   Units
# +------------+---------------------------------------------------------------------------------------------------------------------+-----------------------------------+
#   A_i          Conducting area of insulation material                                                                                 m$^{2}$
#   A_p          Cross-sectional pore area                                                                                              m$^{2}$
#   a_s          Fraction of one-sided leaf area covered by stomata (1 if stomata are on one side only, 2 if they are on both sides)   1
#   a_sh         Fraction of projected area exchanging sensible heat with the air (2)                                                  1
#   alpha_a      Thermal diffusivity of dry air                                                                                         m$^{2}$  s$^{-1}$
#   alpha_l      Leaf albedo, fraction of shortwave radiation reflected by the leaf                                                    1
#   B_l          Boundary layer thickness                                                                                              m
#   beta_B       Bowen ratio (sensible/latent heat flux)                                                                               1
#   c_pa         Specific heat of dry air (1010)                                                                                       J  K$^{-1}$  kg$^{-1}$
#   c_pamol      Molar specific heat of dry air (29.19)                                                                                J  K$^{-1}$  mol$^{-1}$
#   c_pi         Heat capacity of insulation material                                                                                  J  K$^{-1}$  kg$^{-1}$
#   c_pv         Specific heat of water vapour at 300 K                                                                                J  K$^{-1}$  kg$^{-1}$
#   C_wa         Concentration of water in the free air                                                                                mol  m$^{-3}$
#   C_wl         Concentration of water in the leaf air space                                                                          mol  m$^{-3}$
#   d_p          Pore depth                                                                                                            m
#   D_va         Binary diffusion coefficient of water vapour in air                                                                    m$^{2}$  s$^{-1}$
#   Delta_eTa    Slope of saturation vapour pressure at air temperature                                                                Pa  K$^{-1}$
#   dT_i         Temperature increment of insulation material                                                                          K
#   E_l          Latent heat flux from leaf                                                                                            J  m$^{-2}$  s$^{-1}$
#   E_ll         Latent heat flux from lower side of leaf                                                                              J  m$^{-2}$  s$^{-1}$
#   E_lmol       Transpiration rate in molar units                                                                                     mol  m$^{-2}$  s$^{-1}$
#   E_lu         Latent heat flux from upper side of leaf                                                                              J  m$^{-2}$  s$^{-1}$
#   E_w          Latent heat flux from a wet surface                                                                                   J  m$^{-2}$  s$^{-1}$
#   epsilon      Water to air molecular weight ratio (0.622)                                                                           1
#   epsilon_l    Longwave emmissivity of the leaf surface (1.0)                                                                        1
#   F_in_mola    Molar flow rate of dry air into chamber                                                                               mol  s$^{-1}$
#   F_in_molw    Molar flow rate of water vapour into chamber                                                                          mol  s$^{-1}$
#   F_in_v       Volumetric flow rate into chamber                                                                                      m$^{3}$  s$^{-1}$
#   F_in_va_n    Volumetric inflow of dry air at 0oC and 101325 Pa                                                                      m$^{3}$  s$^{-1}$
#   F_out_mola   Molar flow rate of dry air out of chamber                                                                             mol  s$^{-1}$
#   F_out_molw   Molar flow rate of water vapour out of chamber                                                                        mol  s$^{-1}$
#   F_out_v      Volumetric flow rate out of chamber                                                                                    m$^{3}$  s$^{-1}$
#   F_p          Fractional pore area (pore area per unit leaf area)                                                                   1
#   F_s          Fraction of radiation emitted by leaf, absorbed by sensor                                                             1
#   f_u          Wind function in Penman approach, f(u) adapted to energetic units                                                     J  Pa$^{-1}$  m$^{-2}$  s$^{-1}$
#   g            Gravitational acceleration (9.81)                                                                                     m  s$^{-2}$
#   g_bw         Boundary layer conductance to water vapour                                                                            m  s$^{-1}$
#   g_bwmol      Boundary layer conductance to water vapour                                                                            mol  m$^{-2}$  s$^{-1}$
#   g_sp         Diffusive conductance of a stomatal pore                                                                              mol  m$^{-2}$  s$^{-1}$
#   g_sw         Stomatal conductance to water vapour                                                                                  m  s$^{-1}$
#   g_swl        Stomatal conductance to water vapour on lower side                                                                    m  s$^{-1}$
#   g_swmol      Stomatal conductance to water vapour                                                                                  mol  m$^{-2}$  s$^{-1}$
#   g_swu        Stomatal conductance to water vapour on upper side                                                                    m  s$^{-1}$
#   g_tw         Total leaf conductance to water vapour                                                                                m  s$^{-1}$
#   g_twmol      Total leaf layer conductance to water vapour                                                                          mol  m$^{-2}$  s$^{-1}$
#   gamma_v      Psychrometric constant                                                                                                Pa  K$^{-1}$
#   H_c          Chamber height                                                                                                        m
#   h_c          Average 1-sided convective transfer coefficient                                                                       J  K$^{-1}$  m$^{-2}$  s$^{-1}$
#   h_cl         Sensible heat flux coefficient on lower leaf side                                                                     J  K$^{-1}$  m$^{-2}$  s$^{-1}$
#   h_cu         Sensible heat flux coefficient on upper leaf side                                                                     J  K$^{-1}$  m$^{-2}$  s$^{-1}$
#   H_l          Sensible heat flux from leaf                                                                                          J  m$^{-2}$  s$^{-1}$
#   H_ll         Sensible heat flux from lower side of leaf                                                                            J  m$^{-2}$  s$^{-1}$
#   H_lu         Sensible heat flux from upper side of leaf                                                                            J  m$^{-2}$  s$^{-1}$
#   k_a          Thermal conductivity of dry air                                                                                       J  K$^{-1}$  m$^{-1}$  s$^{-1}$
#   k_dv         Ratio $D_{va}/V_m$                                                                                                    mol  m$^{-1}$  s$^{-1}$
#   k_l          Thermal conductivity of a fresh leaf                                                                                  J  K$^{-1}$  m$^{-1}$  s$^{-1}$
#   L_A          Leaf area                                                                                                              m$^{2}$
#   L_c          Chamber length                                                                                                        m
#   L_i          Thickness of insulation material                                                                                      m
#   L_l          Characteristic length scale for convection (size of leaf)                                                             m
#   L_ls         Distance between leaf and net radiation sensor                                                                        m
#   l_p          Pore length                                                                                                           m
#   L_s          Width of net radiation sensor                                                                                         m
#   lambda_E     Latent heat of evaporation (2.45e6)                                                                                   J  kg$^{-1}$
#   lambda_i     Heat conductivity of insulation material                                                                              J  K$^{-1}$  m$^{-1}$  s$^{-1}$
#   M_air        Molar mass of air (kg mol-1)                                                                                          kg  mol$^{-1}$
#   M_N2         Molar mass of nitrogen (0.028)                                                                                        kg  mol$^{-1}$
#   M_O2         Molar mass of oxygen (0.032)                                                                                          kg  mol$^{-1}$
#   M_w          Molar mass of water (0.018)                                                                                           kg  mol$^{-1}$
#   n_c          molar mass of gas in chamber                                                                                          mol
#   Gr           Grashof number                                                                                                        1
#   Le           Lewis number                                                                                                          1
#   n_MU         n=2 for hypostomatous, n=1 for amphistomatous leaves                                                                  1
#   Nu           Nusselt number                                                                                                        1
#   n_p          Pore density                                                                                                           m$^{-2}$
#   Re_c         Critical Reynolds number for the onset of turbulence                                                                  1
#   Re           Reynolds number                                                                                                       1
#   Sh           Sherwood number                                                                                                       1
#   nu_a         Kinematic viscosity of dry air                                                                                         m$^{2}$  s$^{-1}$
#   P_a          Air pressure                                                                                                          Pa
#   P_N2         Partial pressure of nitrogen in the atmosphere                                                                        Pa
#   P_O2         Partial pressure of oxygen in the atmosphere                                                                          Pa
#   P_r          Reference pressure                                                                                                    Pa
#   P_w_in       Vapour pressure of incoming air                                                                                       Pa
#   P_w_out      Vapour pressure of outgoing air                                                                                       Pa
#   P_wa         Vapour pressure in the atmosphere                                                                                     Pa
#   P_was        Saturation vapour pressure at air temperature                                                                         Pa
#   P_wl         Vapour pressure inside the leaf                                                                                       Pa
#   Pr           Prandtl number (0.71)                                                                                                 1
#   Q_i          Heat conduction through insulation material                                                                           J  s$^{-1}$
#   Q_in         Internal heat sources, such as fan                                                                                    J  s$^{-1}$
#   Q_l          Conductive heat flux from upper to lower side of leaf                                                                 J  m$^{-2}$  s$^{-1}$
#   r_a          One-sided boundary layer resistance to heat transfer ($r_H$ in \citet[][P. 231]{monteith_principles_2013})            s  m$^{-1}$
#   r_bw         Boundary layer resistance to water vapour, inverse of $g_{bw}$                                                        s  m$^{-1}$
#   r_bwmol      Leaf BL resistance in molar units                                                                                     s  m$^{2}$  mol$^{-1}$
#   R_d          Downwelling global radiation                                                                                          J  m$^{-2}$  s$^{-1}$
#   r_end        End correction, representing resistance between evaporating sites and pores                                           s  m$^{2}$  mol$^{-1}$
#   R_H_in       Relative humidity of incoming air                                                                                     1
#   R_la         Longwave radiation absorbed by leaf                                                                                   J  m$^{-2}$  s$^{-1}$
#   R_ld         Downwards emitted/reflected global radiation from leaf                                                                J  m$^{-2}$  s$^{-1}$
#   R_ll         Longwave radiation away from leaf                                                                                     J  m$^{-2}$  s$^{-1}$
#   R_lll        Longwave heat flux from lower side of leaf                                                                            J  m$^{-2}$  s$^{-1}$
#   R_llu        Longwave heat flux from upper side of leaf                                                                            J  m$^{-2}$  s$^{-1}$
#   R_lu         Upwards emitted/reflected global radiation from leaf                                                                  J  m$^{-2}$  s$^{-1}$
#   R_mol        Molar gas constant (8.314472)                                                                                         J  K$^{-1}$  mol$^{-1}$
#   r_p          Pore radius (for ellipsoidal pores, half the pore width)                                                              m
#   r_s          Stomatal resistance to water vapour \citep[][P. 231]{monteith_principles_2013}                                        s  m$^{-1}$
#   R_s          Solar shortwave flux                                                                                                  J  m$^{-2}$  s$^{-1}$
#   r_sp         Diffusive resistance of a stomatal pore                                                                               s  m$^{2}$  mol$^{-1}$
#   r_sw         Stomatal resistance to water vapour, inverse of $g_{sw}$                                                              s  m$^{-1}$
#   r_tw         Total leaf resistance to water vapour, $r_{bv} + r_{sv}$                                                              s  m$^{-1}$
#   R_u          Upwelling global radiation                                                                                            J  m$^{-2}$  s$^{-1}$
#   r_v          Leaf BL resistance to water vapour, \citep[][Eq. 13.16]{monteith_principles_2013}                                     s  m$^{-1}$
#   r_vs         Diffusive resistance of a stomatal vapour shell                                                                       s  m$^{2}$  mol$^{-1}$
#   rho_a        Density of dry air                                                                                                    kg  m$^{-3}$
#   rho_al       Density of air at the leaf surface                                                                                    kg  m$^{-3}$
#   rho_i        Density of insulation material                                                                                        kg  m$^{-3}$
#   S            Factor representing stomatal resistance in \citet{penman_physical_1952}                                               1
#   S_a          Radiation sensor above leaf reading                                                                                   J  m$^{-2}$  s$^{-1}$
#   S_b          Radiation sensor below leaf reading                                                                                   J  m$^{-2}$  s$^{-1}$
#   s_p          Spacing between stomata                                                                                               m
#   S_s          Radiation sensor beside leaf reading                                                                                  J  m$^{-2}$  s$^{-1}$
#   sigm         Stefan-Boltzmann constant (5.67e-8)                                                                                   J  K$^{-4}$  m$^{-2}$  s$^{-1}$
#   T0           Freezing point in kelvin                                                                                              K
#   T_a          Air temperature                                                                                                       K
#   T_d          Dew point temperature of incoming air                                                                                 K
#   T_in         Temperature of incoming air                                                                                           K
#   T_l          Leaf temperature                                                                                                      K
#   T_ll         Leaf surface temperature of lower side                                                                                K
#   T_lu         Leaf surface temperature of upper side                                                                                K
#   T_out        Temperature of outgoing air (= chamber T_a)                                                                           K
#   T_r          Reference temperature                                                                                                 K
#   T_room       Lab air temperature                                                                                                   K
#   T_w          Radiative temperature of objects surrounding the leaf                                                                 K
#   V_c          Chamber volume                                                                                                         m$^{3}$
#   V_m          Molar volume of air                                                                                                    m$^{3}$  mol$^{-1}$
#   v_w          Wind velocity                                                                                                         m  s$^{-1}$
#   W_c          Chamber width                                                                                                         m
#   z_l          Leaf thickness (m)                                                                                                    m

# %%
latex(table(tabledata))
# Out:
# \begin{tabular}{lll}
# Variable & Description (value) & Units \\
# $A_{i}$ & Conducting area of insulation material &  m$^{2}$  \\
# $A_{p}$ & Cross-sectional pore area &  m$^{2}$  \\
# $a_{s}$ & Fraction of one-sided leaf area covered by stomata (1 if stomata are on one side only, 2 if they are on both sides) & 1  \\
# $a_{\mathit{sh}}$ & Fraction of projected area exchanging sensible heat with the air (2) & 1  \\
# $\alpha_{a}$ & Thermal diffusivity of dry air &  m$^{2}$  s$^{-1}$  \\
# $\alpha_{l}$ & Leaf albedo, fraction of shortwave radiation reflected by the leaf & 1  \\
# $B_{l}$ & Boundary layer thickness & m  \\
# $\beta_{B}$ & Bowen ratio (sensible/latent heat flux) & 1  \\
# $c_{\mathit{pa}}$ & Specific heat of dry air (1010)  & J  K$^{-1}$  kg$^{-1}$  \\
# $c_{\mathit{pamol}}$ & Molar specific heat of dry air (29.19)  & J  K$^{-1}$  mol$^{-1}$  \\
# $c_{\pi}$ & Heat capacity of insulation material & J  K$^{-1}$  kg$^{-1}$  \\
# $c_{\mathit{pv}}$ & Specific heat of water vapour at 300 K & J  K$^{-1}$  kg$^{-1}$  \\
# $C_{\mathit{wa}}$ & Concentration of water in the free air  & mol  m$^{-3}$  \\
# $C_{\mathit{wl}}$ & Concentration of water in the leaf air space  & mol  m$^{-3}$  \\
# $d_{p}$ & Pore depth & m  \\
# $D_{\mathit{va}}$ & Binary diffusion coefficient of water vapour in air &  m$^{2}$  s$^{-1}$  \\
# $\Delta_{\mathit{eTa}}$ & Slope of saturation vapour pressure at air temperature & Pa  K$^{-1}$  \\
# $\mathit{dT}_{i}$ & Temperature increment of insulation material & K  \\
# $E_{l}$ & Latent heat flux from leaf & J  m$^{-2}$  s$^{-1}$  \\
# $E_{\mathit{ll}}$ & Latent heat flux from lower side of leaf & J  m$^{-2}$  s$^{-1}$  \\
# $E_{\mathit{lmol}}$ & Transpiration rate in molar units & mol  m$^{-2}$  s$^{-1}$  \\
# $E_{\mathit{lu}}$ & Latent heat flux from upper side of leaf & J  m$^{-2}$  s$^{-1}$  \\
# $E_{w}$ & Latent heat flux from a wet surface & J  m$^{-2}$  s$^{-1}$  \\
# $\epsilon$ & Water to air molecular weight ratio (0.622) & 1  \\
# $\epsilon_{l}$ & Longwave emmissivity of the leaf surface (1.0) & 1  \\
# $F_{\mathit{in}_{\mathit{mola}}}$ & Molar flow rate of dry air into chamber & mol  s$^{-1}$  \\
# $F_{\mathit{in}_{\mathit{molw}}}$ & Molar flow rate of water vapour into chamber & mol  s$^{-1}$  \\
# $F_{\mathit{in}_{v}}$ & Volumetric flow rate into chamber &  m$^{3}$  s$^{-1}$  \\
# $F_{\mathit{in}_{\mathit{va}_{n}}}$ & Volumetric inflow of dry air at 0oC and 101325 Pa &  m$^{3}$  s$^{-1}$  \\
# $F_{\mathit{out}_{\mathit{mola}}}$ & Molar flow rate of dry air out of chamber & mol  s$^{-1}$  \\
# $F_{\mathit{out}_{\mathit{molw}}}$ & Molar flow rate of water vapour out of chamber & mol  s$^{-1}$  \\
# $F_{\mathit{out}_{v}}$ & Volumetric flow rate out of chamber &  m$^{3}$  s$^{-1}$  \\
# $F_{p}$ & Fractional pore area (pore area per unit leaf area) & 1  \\
# $F_{s}$ & Fraction of radiation emitted by leaf, absorbed by sensor & 1  \\
# $f_{u}$ & Wind function in Penman approach, f(u) adapted to energetic units & J  Pa$^{-1}$  m$^{-2}$  s$^{-1}$  \\
# $g$ & Gravitational acceleration (9.81) & m  s$^{-2}$  \\
# $g_{\mathit{bw}}$ & Boundary layer conductance to water vapour  & m  s$^{-1}$  \\
# $g_{\mathit{bwmol}}$ & Boundary layer conductance to water vapour  & mol  m$^{-2}$  s$^{-1}$  \\
# $g_{\mathit{sp}}$ & Diffusive conductance of a stomatal pore & mol  m$^{-2}$  s$^{-1}$  \\
# $g_{\mathit{sw}}$ & Stomatal conductance to water vapour & m  s$^{-1}$  \\
# $g_{\mathit{swl}}$ & Stomatal conductance to water vapour on lower side & m  s$^{-1}$  \\
# $g_{\mathit{swmol}}$ & Stomatal conductance to water vapour & mol  m$^{-2}$  s$^{-1}$  \\
# $g_{\mathit{swu}}$ & Stomatal conductance to water vapour on upper side & m  s$^{-1}$  \\
# $g_{\mathit{tw}}$ & Total leaf conductance to water vapour & m  s$^{-1}$  \\
# $g_{\mathit{twmol}}$ & Total leaf layer conductance to water vapour & mol  m$^{-2}$  s$^{-1}$  \\
# $\gamma_{v}$ & Psychrometric constant & Pa  K$^{-1}$  \\
# $H_{c}$ & Chamber height & m  \\
# $h_{c}$ & Average 1-sided convective transfer coefficient & J  K$^{-1}$  m$^{-2}$  s$^{-1}$  \\
# $h_{\mathit{cl}}$ & Sensible heat flux coefficient on lower leaf side & J  K$^{-1}$  m$^{-2}$  s$^{-1}$  \\
# $h_{\mathit{cu}}$ & Sensible heat flux coefficient on upper leaf side & J  K$^{-1}$  m$^{-2}$  s$^{-1}$  \\
# $H_{l}$ & Sensible heat flux from leaf & J  m$^{-2}$  s$^{-1}$  \\
# $H_{\mathit{ll}}$ & Sensible heat flux from lower side of leaf & J  m$^{-2}$  s$^{-1}$  \\
# $H_{\mathit{lu}}$ & Sensible heat flux from upper side of leaf & J  m$^{-2}$  s$^{-1}$  \\
# $k_{a}$ & Thermal conductivity of dry air & J  K$^{-1}$  m$^{-1}$  s$^{-1}$  \\
# $k_{\mathit{dv}}$ & Ratio $D_{va}/V_m$ & mol  m$^{-1}$  s$^{-1}$  \\
# $k_{l}$ & Thermal conductivity of a fresh leaf & J  K$^{-1}$  m$^{-1}$  s$^{-1}$  \\
# $L_{A}$ & Leaf area &  m$^{2}$  \\
# $L_{c}$ & Chamber length & m  \\
# $L_{i}$ & Thickness of insulation material & m  \\
# $L_{l}$ & Characteristic length scale for convection (size of leaf) & m  \\
# $L_{\mathit{ls}}$ & Distance between leaf and net radiation sensor & m  \\
# $l_{p}$ & Pore length & m  \\
# $L_{s}$ & Width of net radiation sensor & m  \\
# $\lambda_{E}$ & Latent heat of evaporation (2.45e6) & J  kg$^{-1}$  \\
# $\lambda_{i}$ & Heat conductivity of insulation material & J  K$^{-1}$  m$^{-1}$  s$^{-1}$  \\
# $M_{\mathit{air}}$ & Molar mass of air (kg mol-1) & kg  mol$^{-1}$  \\
# $M_{N_{2}}$ & Molar mass of nitrogen (0.028) & kg  mol$^{-1}$  \\
# $M_{O_{2}}$ & Molar mass of oxygen (0.032) & kg  mol$^{-1}$  \\
# $M_{w}$ & Molar mass of water (0.018) & kg  mol$^{-1}$  \\
# $n_{c}$ & molar mass of gas in chamber & mol  \\
# $\mathit{Gr}$ & Grashof number & 1  \\
# $\mathit{Le}$ & Lewis number & 1  \\
# $n_{\mathit{MU}}$ & n=2 for hypostomatous, n=1 for amphistomatous leaves & 1  \\
# $\mathit{Nu}$ & Nusselt number & 1  \\
# $n_{p}$ & Pore density &  m$^{-2}$  \\
# $\mathit{Re}_{c}$ & Critical Reynolds number for the onset of turbulence & 1  \\
# $\mathit{Re}$ & Reynolds number & 1  \\
# $\mathit{Sh}$ & Sherwood number & 1  \\
# $\nu_{a}$ & Kinematic viscosity of dry air &  m$^{2}$  s$^{-1}$  \\
# $P_{a}$ & Air pressure & Pa  \\
# $P_{N_{2}}$ & Partial pressure of nitrogen in the atmosphere & Pa  \\
# $P_{O_{2}}$ & Partial pressure of oxygen in the atmosphere & Pa  \\
# $P_{r}$ & Reference pressure & Pa  \\
# $P_{w_{\mathit{in}}}$ & Vapour pressure of incoming air & Pa  \\
# $P_{w_{\mathit{out}}}$ & Vapour pressure of outgoing air & Pa  \\
# $P_{\mathit{wa}}$ & Vapour pressure in the atmosphere & Pa  \\
# $P_{\mathit{was}}$ & Saturation vapour pressure at air temperature & Pa  \\
# $P_{\mathit{wl}}$ & Vapour pressure inside the leaf & Pa  \\
# $\mathit{Pr}$ & Prandtl number (0.71) & 1  \\
# $Q_{i}$ & Heat conduction through insulation material & J  s$^{-1}$  \\
# $Q_{\mathit{in}}$ & Internal heat sources, such as fan & J  s$^{-1}$  \\
# $Q_{l}$ & Conductive heat flux from upper to lower side of leaf & J  m$^{-2}$  s$^{-1}$  \\
# $r_{a}$ & One-sided boundary layer resistance to heat transfer ($r_H$ in \citet[][P. 231]{monteith_principles_2013}) & s  m$^{-1}$  \\
# $r_{\mathit{bw}}$ & Boundary layer resistance to water vapour, inverse of $g_{bw}$ & s  m$^{-1}$  \\
# $r_{\mathit{bwmol}}$ & Leaf BL resistance in molar units & s  m$^{2}$  mol$^{-1}$  \\
# $R_{d}$ & Downwelling global radiation & J  m$^{-2}$  s$^{-1}$  \\
# $r_{\mathit{end}}$ & End correction, representing resistance between evaporating sites and pores & s  m$^{2}$  mol$^{-1}$  \\
# $R_{H_{\mathit{in}}}$ & Relative humidity of incoming air & 1  \\
# $R_{\mathit{la}}$ & Longwave radiation absorbed by leaf & J  m$^{-2}$  s$^{-1}$  \\
# $R_{\mathit{ld}}$ & Downwards emitted/reflected global radiation from leaf & J  m$^{-2}$  s$^{-1}$  \\
# $R_{\mathit{ll}}$ & Longwave radiation away from leaf & J  m$^{-2}$  s$^{-1}$  \\
# $R_{\mathit{lll}}$ & Longwave heat flux from lower side of leaf & J  m$^{-2}$  s$^{-1}$  \\
# $R_{\mathit{llu}}$ & Longwave heat flux from upper side of leaf & J  m$^{-2}$  s$^{-1}$  \\
# $R_{\mathit{lu}}$ & Upwards emitted/reflected global radiation from leaf & J  m$^{-2}$  s$^{-1}$  \\
# $R_{\mathit{mol}}$ & Molar gas constant (8.314472) & J  K$^{-1}$  mol$^{-1}$  \\
# $r_{p}$ & Pore radius (for ellipsoidal pores, half the pore width) & m  \\
# $r_{s}$ & Stomatal resistance to water vapour \citep[][P. 231]{monteith_principles_2013} & s  m$^{-1}$  \\
# $R_{s}$ & Solar shortwave flux & J  m$^{-2}$  s$^{-1}$  \\
# $r_{\mathit{sp}}$ & Diffusive resistance of a stomatal pore & s  m$^{2}$  mol$^{-1}$  \\
# $r_{\mathit{sw}}$ & Stomatal resistance to water vapour, inverse of $g_{sw}$ & s  m$^{-1}$  \\
# $r_{\mathit{tw}}$ & Total leaf resistance to water vapour, $r_{bv} + r_{sv}$ & s  m$^{-1}$  \\
# $R_{u}$ & Upwelling global radiation & J  m$^{-2}$  s$^{-1}$  \\
# $r_{v}$ & Leaf BL resistance to water vapour, \citep[][Eq. 13.16]{monteith_principles_2013} & s  m$^{-1}$  \\
# $r_{\mathit{vs}}$ & Diffusive resistance of a stomatal vapour shell & s  m$^{2}$  mol$^{-1}$  \\
# $\rho_{a}$ & Density of dry air & kg  m$^{-3}$  \\
# $\rho_{\mathit{al}}$ & Density of air at the leaf surface & kg  m$^{-3}$  \\
# $\rho_{i}$ & Density of insulation material & kg  m$^{-3}$  \\
# $S$ & Factor representing stomatal resistance in \citet{penman_physical_1952} & 1  \\
# $S_{a}$ & Radiation sensor above leaf reading & J  m$^{-2}$  s$^{-1}$  \\
# $S_{b}$ & Radiation sensor below leaf reading & J  m$^{-2}$  s$^{-1}$  \\
# $s_{p}$ & Spacing between stomata & m  \\
# $S_{s}$ & Radiation sensor beside leaf reading & J  m$^{-2}$  s$^{-1}$  \\
# $\mathit{sigm}$ & Stefan-Boltzmann constant (5.67e-8) & J  K$^{-4}$  m$^{-2}$  s$^{-1}$  \\
# $T_{0}$ & Freezing point in kelvin & K  \\
# $T_{a}$ & Air temperature & K  \\
# $T_{d}$ & Dew point temperature of incoming air & K  \\
# $T_{\mathit{in}}$ & Temperature of incoming air & K  \\
# $T_{l}$ & Leaf temperature & K  \\
# $T_{\mathit{ll}}$ & Leaf surface temperature of lower side & K  \\
# $T_{\mathit{lu}}$ & Leaf surface temperature of upper side & K  \\
# $T_{\mathit{out}}$ & Temperature of outgoing air (= chamber T_a) & K  \\
# $T_{r}$ & Reference temperature & K  \\
# $T_{\mathit{room}}$ & Lab air temperature & K  \\
# $T_{w}$ & Radiative temperature of objects surrounding the leaf & K  \\
# $V_{c}$ & Chamber volume &  m$^{3}$  \\
# $V_{m}$ & Molar volume of air &  m$^{3}$  mol$^{-1}$  \\
# $v_{w}$ & Wind velocity & m  s$^{-1}$  \\
# $W_{c}$ & Chamber width & m  \\
# $z_{l}$ & Leaf thickness (m) & m  \\
# \end{tabular}
